# %%
import pandas as pd
import numpy as np

# %%
fifa21 = pd.read_csv("fifa21_train.csv")
print(fifa21.shape)
# Out:
# (11701, 101)

# %%
fifa21.head()
# Out:
#        ID           Name  Age  Nationality                        Club   BP  \
# 0  184383      A. Pasche   26  Switzerland           FC Lausanne-Sport   CM
# 1  188044  Alan Carvalho   30     China PR     Beijing Sinobo Guoan FC   ST
# 2  184431    S. Giovinco   33        Italy                    Al Hilal  CAM
# 3  233796       J. Evans   22        Wales                Swansea City  CDM
# 4  234799     Y. Demoncy   23       France  US Orléans Loiret Football  CDM
#
#    Position                               Team & Contract Height  Weight  ...  \
# 0    CM CDM                 FC Lausanne-Sport 2015 ~ 2020   5'9"  161lbs  ...
# 1  ST LW LM  Beijing Sinobo Guoan FC Dec 31, 2020 On Loan   6'0"  159lbs  ...
# 2    CAM CF                          Al Hilal 2019 ~ 2022   5'4"  134lbs  ...
# 3    CDM CM                      Swansea City 2016 ~ 2021  5'10"  152lbs  ...
# 4    CDM CM        US Orléans Loiret Football 2018 ~ 2021  5'11"  150lbs  ...
#
# ...

# %%
fifa21_numerical = fifa21.select_dtypes(include=np.number)

# %%
fifa21_numerical.head()
# Out:
#        ID  Age  Growth  Attacking  Crossing  Finishing  Heading Accuracy  \
# 0  184383   26       1        258        54         47                43
# 1  188044   30       0        365        66         79                76
# 2  184431   33       0        336        73         76                34
# 3  233796   22      13        242        44         42                58
# 4  234799   23       8        249        49         37                61
#
#    Short Passing  Volleys  Skill  ...  GK Reflexes  Total Stats  Base Stats  \
# 0             70     44.0    286  ...            6         1682         357
# 1             68     76.0    375  ...           16         1961         412
# 2             78     75.0    424  ...            3         1925         404
# 3             62     36.0    259  ...           12         1527         329
# 4             68     34.0    280  ...           15         1664         360
#
#    PAC  SHO  PAS  DRI  DEF  PHY  OVA
# ...

# %%
fifa21_numerical.isna().sum()
# Out:
# ID                    0
# Age                   0
# Growth                0
# Attacking             0
# Crossing              0
# Finishing             0
# Heading Accuracy      0
# Short Passing         0
# Volleys              41
# Skill                 0
# Dribbling             0
# Curve                41
# FK Accuracy           0
# Long Passing          0
# Ball Control          0
# Movement              0
# Acceleration          0
# Sprint Speed          0
# Agility              41
# Reactions             0
# Balance              41
# Power                 0
# Shot Power            0
# Jumping              41
# Stamina               0
# Strength              0
# Long Shots            0
# Mentality             0
# Aggression            0
# Interceptions         7
# Positioning           7
# Vision               41
# Penalties             0
# Composure           279
# Defending             0
# Marking               0
# Standing Tackle       0
# Sliding Tackle       41
# ...

# %%
cols = []
for i in range(len(fifa21_numerical.columns)):
    cols.append(fifa21_numerical.columns[i].lower())
fifa21_numerical.columns = cols

print("Lowercase version fifa21")
display(fifa21_numerical.head(1))
# Out:
# Lowercase version fifa21
#        id  age  growth  attacking  crossing  finishing  heading accuracy  \
# 0  184383   26       1        258        54         47                43
#
#    short passing  volleys  skill  ...  gk reflexes  total stats  base stats  \
# 0             70     44.0    286  ...            6         1682         357
#
#    pac  sho  pas  dri  def  phy  ova
# 0   69   51   63   63   51   60   64
#
# [1 rows x 53 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig, ax1 = plt.subplots(4,3,figsize=(20,20)) 
sns.histplot(x ='volleys',data = fifa21_numerical ,bins = 20,color='tab:green', ax = ax1[0,0])
sns.histplot(x ='curve',data = fifa21_numerical,bins = 20,color='tab:green', ax = ax1[0,1])
sns.histplot(x ='agility',data = fifa21_numerical,bins = 20,color='tab:green', ax = ax1[0,2])
sns.histplot(x ='balance',data = fifa21_numerical,bins = 20,color='tab:green', ax = ax1[1,0])
sns.histplot(x ='jumping',data = fifa21_numerical,bins = 20,color='tab:green', ax = ax1[1,1])
sns.histplot(x ='interceptions',data = fifa21_numerical ,bins = 20,color='tab:green', ax = ax1[1,2])
sns.histplot(x ='positioning',data = fifa21_numerical ,bins = 20,color='tab:green', ax = ax1[2,0])
sns.histplot(x ='vision',data = fifa21_numerical, bins=  20,color='tab:green', ax = ax1[2,1])
sns.histplot(x ='composure',data = fifa21_numerical ,bins = 20,color='tab:green', ax = ax1[2,2])
sns.histplot(x ='sliding tackle',data = fifa21_numerical ,bins = 20,color='tab:green', ax = ax1[3,0])
plt.show()

# %%
fifa21_numerical_noNaN=fifa21_numerical.fillna((fifa21_numerical.mean()))

# %%
fifa21_numerical_noNaN.isna().sum()
# Out:
# id                  0
# age                 0
# growth              0
# attacking           0
# crossing            0
# finishing           0
# heading accuracy    0
# short passing       0
# volleys             0
# skill               0
# dribbling           0
# curve               0
# fk accuracy         0
# long passing        0
# ball control        0
# movement            0
# acceleration        0
# sprint speed        0
# agility             0
# reactions           0
# balance             0
# power               0
# shot power          0
# jumping             0
# stamina             0
# strength            0
# long shots          0
# mentality           0
# aggression          0
# interceptions       0
# positioning         0
# vision              0
# penalties           0
# composure           0
# defending           0
# marking             0
# standing tackle     0
# sliding tackle      0
# goalkeeping         0
# gk diving           0
# gk handling         0
# ...

# %%
fifa21_categorical = fifa21.select_dtypes(exclude=np.number)
fifa21_categorical.head()
pd.set_option('display.max_columns', None)
fifa21_categorical.head()
# Out:
#             Name  Nationality                        Club   BP  Position  \
# 0      A. Pasche  Switzerland           FC Lausanne-Sport   CM    CM CDM
# 1  Alan Carvalho     China PR     Beijing Sinobo Guoan FC   ST  ST LW LM
# 2    S. Giovinco        Italy                    Al Hilal  CAM    CAM CF
# 3       J. Evans        Wales                Swansea City  CDM    CDM CM
# 4     Y. Demoncy       France  US Orléans Loiret Football  CDM    CDM CM
#
#                                 Team & Contract Height  Weight   foot  \
# 0                 FC Lausanne-Sport 2015 ~ 2020   5'9"  161lbs  Right
# 1  Beijing Sinobo Guoan FC Dec 31, 2020 On Loan   6'0"  159lbs  Right
# 2                          Al Hilal 2019 ~ 2022   5'4"  134lbs  Right
# 3                      Swansea City 2016 ~ 2021  5'10"  152lbs  Right
# 4        US Orléans Loiret Football 2018 ~ 2021  5'11"  150lbs  Right
#
#          Joined Loan Date End  Value  Wage Release Clause  \
# ...

# %%
cols = []
for i in range(len(fifa21_categorical.columns)):
    cols.append(fifa21_categorical.columns[i].lower())
fifa21_categorical.columns = cols

print("Lowercase version fifa21")
display(fifa21_categorical.head(1))
# Out:
# Lowercase version fifa21
#         name  nationality               club  bp position  \
# 0  A. Pasche  Switzerland  FC Lausanne-Sport  CM   CM CDM
#
#                  team & contract height  weight   foot       joined  \
# 0  FC Lausanne-Sport 2015 ~ 2020   5'9"  161lbs  Right  Jul 1, 2015
#
#   loan date end  value wage release clause     contract  w/f  sm   a/w  \
# 0           NaN  €525K  €4K          €801K  2015 ~ 2020  4 ★  2★  High
#
#       d/w   ir hits    ls    st    rs    lw    lf    cf    rf    rw   lam  \
# 0  Medium  1 ★    3  58+1  58+1  58+1  61+0  62+0  62+0  62+0  61+0  63+1
#
#     cam   ram    lm   lcm    cm   rcm    rm   lwb   ldm   cdm   rdm   rwb  \
# 0  63+1  63+1  63+1  63+1  63+1  63+1  63+1  59+1  59+1  59+1  59+1  59+1
#
#      lb   lcb    cb   rcb    rb    gk
# 0  58+1  54+1  54+1  54+1  58+1  15+1

# %%
fifa21_categorical_l=fifa21_categorical.iloc[:,:21]

# %%
fifa21_categorical_r=fifa21_categorical.iloc[:,22:]

# %%
fifa21_categorical_r.head()
# Out:
#      st    rs    lw    lf    cf    rf    rw   lam   cam   ram    lm   lcm  \
# 0  58+1  58+1  61+0  62+0  62+0  62+0  61+0  63+1  63+1  63+1  63+1  63+1
# 1  77+0  77+0  77+0  77+0  77+0  77+0  77+0  76+1  76+1  76+1  76+1  68+2
# 2  73+2  73+2  80+0  79+0  79+0  79+0  80+0  80+0  80+0  80+0  79+1  74+2
# 3  50+2  50+2  51+0  51+0  51+0  51+0  51+0  53+2  53+2  53+2  53+2  56+2
# 4  56+2  56+2  59+0  59+0  59+0  59+0  59+0  61+2  61+2  61+2  62+2  63+2
#
#      cm   rcm    rm   lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb  \
# 0  63+1  63+1  63+1  59+1  59+1  59+1  59+1  59+1  58+1  54+1  54+1  54+1
# 1  68+2  68+2  76+1  57+2  53+2  53+2  53+2  57+2  53+2  48+2  48+2  48+2
# 2  74+2  74+2  79+1  59+2  56+2  56+2  56+2  59+2  53+2  41+2  41+2  41+2
# 3  56+2  56+2  53+2  56+2  58+2  58+2  58+2  56+2  57+2  58+2  58+2  58+2
# 4  63+2  63+2  62+2  64+2  64+2  64+2  64+2  64+2  63+2  61+2  61+2  61+2
#
#      rb    gk
# 0  58+1  15+1
# 1  53+2  18+2
# 2  53+2  12+2
# ...

# %%
def add_values(text):
    return sum([int(x) for x in text.split('+')])

# %%
aux_df = fifa21_categorical_r.copy()
for col in fifa21_categorical_r.columns:
    aux_df[col] = fifa21_categorical_r[col].apply(add_values)
    
aux_df.head()
# Out:
#    st  rs  lw  lf  cf  rf  rw  lam  cam  ram  lm  lcm  cm  rcm  rm  lwb  ldm  \
# 0  59  59  61  62  62  62  61   64   64   64  64   64  64   64  64   60   60
# 1  77  77  77  77  77  77  77   77   77   77  77   70  70   70  77   59   55
# 2  75  75  80  79  79  79  80   80   80   80  80   76  76   76  80   61   58
# 3  52  52  51  51  51  51  51   55   55   55  55   58  58   58  55   58   60
# 4  58  58  59  59  59  59  59   63   63   63  64   65  65   65  64   66   66
#
#    cdm  rdm  rwb  lb  lcb  cb  rcb  rb  gk
# 0   60   60   60  59   55  55   55  59  16
# 1   55   55   59  55   50  50   50  55  20
# 2   58   58   61  55   43  43   43  55  14
# 3   60   60   58  59   60  60   60  59  16
# 4   66   66   66  65   63  63   63  65  17

# %%
aux_df.isna().sum()
# Out:
# st     0
# rs     0
# lw     0
# lf     0
# cf     0
# rf     0
# rw     0
# lam    0
# cam    0
# ram    0
# lm     0
# lcm    0
# cm     0
# rcm    0
# rm     0
# lwb    0
# ldm    0
# cdm    0
# rdm    0
# rwb    0
# lb     0
# lcb    0
# cb     0
# rcb    0
# rb     0
# gk     0
# dtype: int64

# %%
fifa21_categorical_l=fifa21_categorical.iloc[:,:21]
fifa21_categorical_l.head()
# Out:
#             name  nationality                        club   bp  position  \
# 0      A. Pasche  Switzerland           FC Lausanne-Sport   CM    CM CDM
# 1  Alan Carvalho     China PR     Beijing Sinobo Guoan FC   ST  ST LW LM
# 2    S. Giovinco        Italy                    Al Hilal  CAM    CAM CF
# 3       J. Evans        Wales                Swansea City  CDM    CDM CM
# 4     Y. Demoncy       France  US Orléans Loiret Football  CDM    CDM CM
#
#                                 team & contract height  weight   foot  \
# 0                 FC Lausanne-Sport 2015 ~ 2020   5'9"  161lbs  Right
# 1  Beijing Sinobo Guoan FC Dec 31, 2020 On Loan   6'0"  159lbs  Right
# 2                          Al Hilal 2019 ~ 2022   5'4"  134lbs  Right
# 3                      Swansea City 2016 ~ 2021  5'10"  152lbs  Right
# 4        US Orléans Loiret Football 2018 ~ 2021  5'11"  150lbs  Right
#
#          joined loan date end  value  wage release clause  \
# ...

# %%
fifa21_categorical_l_stars=fifa21_categorical_l[['w/f','sm', 'ir']]

# %%
fifa21_categorical_l_stars.head()
# Out:
#    w/f  sm   ir
# 0  4 ★  2★  1 ★
# 1  3 ★  4★  2 ★
# 2  4 ★  4★  2 ★
# 3  2 ★  2★  1 ★
# 4  2 ★  3★  1 ★

# %%
def stars(text):
    return text[0]

# %%
a = "2★"

# %%
a[0]
# Out:
# '2'

# %%
fifa21_stars = fifa21_categorical_l_stars.copy()
for col in fifa21_categorical_l_stars.columns:
    fifa21_stars[col] = fifa21_categorical_l_stars[col].apply(stars)
    
fifa21_stars.head()
# Out:
#   w/f sm ir
# 0   4  2  1
# 1   3  4  2
# 2   4  4  2
# 3   2  2  1
# 4   2  3  1

# %%
fifa21_categorical_l_money=fifa21_categorical_l[['value','wage', 'release clause']]

# %%
fifa21_categorical_l_money.head()
# Out:
#    value  wage release clause
# 0  €525K   €4K          €801K
# 1  €8.5M  €23K             €0
# 2    €9M  €49K         €15.3M
# 3  €275K   €4K          €694K
# 4  €725K   €2K          €1.4M

# %%
def money(text):
    return text.replace("€", "")

# %%
fifa21_money = fifa21_categorical_l_money.copy()
for col in fifa21_categorical_l_money.columns:
    fifa21_money[col] = fifa21_categorical_l_money[col].apply(money)
    
fifa21_money.head()
# Out:
#   value wage release clause
# 0  525K   4K           801K
# 1  8.5M  23K              0
# 2    9M  49K          15.3M
# 3  275K   4K           694K
# 4  725K   2K           1.4M

# %%
def money2(text):
    return text.replace("K", "")

fifa21_money2 = fifa21_money.copy()
for col in fifa21_money.columns:
    fifa21_money2[col] = fifa21_money[col].apply(money2)
    
fifa21_money2.head()
# Out:
#   value wage release clause
# 0   525    4            801
# 1  8.5M   23              0
# 2    9M   49          15.3M
# 3   275    4            694
# 4   725    2           1.4M

# %%
def money3(text):
    return text.replace("M", "")

fifa21_money3 = fifa21_money2.copy()
for col in fifa21_money2.columns:
    fifa21_money3[col] = fifa21_money2[col].apply(money3)
    
fifa21_money3.head()
# Out:
#   value wage release clause
# 0   525    4            801
# 1   8.5   23              0
# 2     9   49           15.3
# 3   275    4            694
# 4   725    2            1.4

# %%
fifa21_categorical_l_weight=fifa21_categorical_l[['weight']]
fifa21_categorical_l_weight.head()
# Out:
#    weight
# 0  161lbs
# 1  159lbs
# 2  134lbs
# 3  152lbs
# 4  150lbs

# %%
def weight(text):
    return text.replace("lbs", "")

fifa21_weight = fifa21_categorical_l_weight.copy()
for col in fifa21_categorical_l_weight.columns:
    fifa21_weight[col] = fifa21_categorical_l_weight[col].apply(weight)
    
fifa21_weight.head()
# Out:
#   weight
# 0    161
# 1    159
# 2    134
# 3    152
# 4    150

# %%
fifa21_categorical_l_height=fifa21_categorical_l[['height']]
fifa21_categorical_l_height.head()
# Out:
#   height
# 0   5'9"
# 1   6'0"
# 2   5'4"
# 3  5'10"
# 4  5'11"

# %%
def height(text):
    return text.replace("'", ".").replace('"' , '')

fifa21_height = fifa21_categorical_l_height.copy()
for col in fifa21_categorical_l_height.columns:
    fifa21_height[col] = fifa21_categorical_l_height[col].apply(height)
    
fifa21_height.head()
# Out:
#   height
# 0    5.9
# 1    6.0
# 2    5.4
# 3   5.10
# 4   5.11

# %%
fifa21_categorical_l.isna().sum()
# Out:
# name                   0
# nationality            0
# club                  18
# bp                     0
# position             288
# team & contract        0
# height                 0
# weight                 0
# foot                   0
# joined                41
# loan date end      11072
# value                  0
# wage                   0
# release clause         0
# contract               0
# w/f                    0
# sm                     0
# a/w                   59
# d/w                   59
# ir                     0
# hits                   0
# dtype: int64

# %%
#drop loan date end because there are too many NaN.
fifa21_categorical_l_dropped = fifa21_categorical_l.drop(['loan date end'], axis=1) # axis = 1 -> columns
fifa21_categorical_l_dropped.head()
# Out:
#             name  nationality                        club   bp  position  \
# 0      A. Pasche  Switzerland           FC Lausanne-Sport   CM    CM CDM
# 1  Alan Carvalho     China PR     Beijing Sinobo Guoan FC   ST  ST LW LM
# 2    S. Giovinco        Italy                    Al Hilal  CAM    CAM CF
# 3       J. Evans        Wales                Swansea City  CDM    CDM CM
# 4     Y. Demoncy       France  US Orléans Loiret Football  CDM    CDM CM
#
#                                 team & contract height  weight   foot  \
# 0                 FC Lausanne-Sport 2015 ~ 2020   5'9"  161lbs  Right
# 1  Beijing Sinobo Guoan FC Dec 31, 2020 On Loan   6'0"  159lbs  Right
# 2                          Al Hilal 2019 ~ 2022   5'4"  134lbs  Right
# 3                      Swansea City 2016 ~ 2021  5'10"  152lbs  Right
# 4        US Orléans Loiret Football 2018 ~ 2021  5'11"  150lbs  Right
#
#          joined  value  wage release clause              contract  w/f  sm  \
# ...

# %%
#mode_position = fifa21_categorical_l_dropped['position'].mode()
#mode_position
#fifa21_categorical_l_dropped['position'] = fifa21_categorical_l_dropped['position'].fillna(mode_position)

# %%
fifa21_categorical_l_dropped.isna().sum()
# Out:
# name                 0
# nationality          0
# club                18
# bp                   0
# position           288
# team & contract      0
# height               0
# weight               0
# foot                 0
# joined              41
# value                0
# wage                 0
# release clause       0
# contract             0
# w/f                  0
# sm                   0
# a/w                 59
# d/w                 59
# ir                   0
# hits                 0
# dtype: int64

# %%
#mode_position = fifa21_categorical_l_dropped['club'].mode()
#mode_position[0]
#fifa21_categorical_l_dropped['position'] = fifa21_categorical_l_dropped['position'].fillna(0)
#fifa21_categorical_l_dropped.isna().sum()

# %%
aux_df = fifa21_categorical_l_dropped.copy()
for column in ['club', 'position', 'joined', 'a/w', 'd/w']:
    mode = aux_df[column].mode()
    aux_df[column] = aux_df[column].fillna(mode[0])   
    
aux_df.club.isna().sum()
# Out:
# 0

# %%
aux_df.isna().sum()
# Out:
# name               0
# nationality        0
# club               0
# bp                 0
# position           0
# team & contract    0
# height             0
# weight             0
# foot               0
# joined             0
# value              0
# wage               0
# release clause     0
# contract           0
# w/f                0
# sm                 0
# a/w                0
# d/w                0
# ir                 0
# hits               0
# dtype: int64

# %%
fifa21_numerical.isna().sum()
# Out:
# id                    0
# age                   0
# growth                0
# attacking             0
# crossing              0
# finishing             0
# heading accuracy      0
# short passing         0
# volleys              41
# skill                 0
# dribbling             0
# curve                41
# fk accuracy           0
# long passing          0
# ball control          0
# movement              0
# acceleration          0
# sprint speed          0
# agility              41
# reactions             0
# balance              41
# power                 0
# shot power            0
# jumping              41
# stamina               0
# strength              0
# long shots            0
# mentality             0
# aggression            0
# interceptions         7
# positioning           7
# vision               41
# penalties             0
# composure           279
# defending             0
# marking               0
# standing tackle       0
# sliding tackle       41
# ...

# %%
fifa21_numerical.head()
# Out:
#        id  age  growth  attacking  crossing  finishing  heading accuracy  \
# 0  184383   26       1        258        54         47                43
# 1  188044   30       0        365        66         79                76
# 2  184431   33       0        336        73         76                34
# 3  233796   22      13        242        44         42                58
# 4  234799   23       8        249        49         37                61
#
#    short passing  volleys  skill  dribbling  curve  fk accuracy  long passing  \
# 0             70     44.0    286         61   44.0           55            63
# 1             68     76.0    375         83   78.0           72            63
# 2             78     75.0    424         85   89.0           91            74
# 3             62     36.0    259         54   41.0           46            57
# 4             68     34.0    280         64   44.0           45            61
#
# ...

# %%
count=fifa21_numerical.describe().T

# %%
count[count['count']<11701]
# Out:
#                   count       mean        std   min   25%   50%   75%   max
# volleys         11660.0  45.067324  17.732902   4.0  32.0  47.0  59.0  90.0
# curve           11660.0  49.617839  18.180408   4.0  37.0  52.0  64.0  94.0
# agility         11660.0  64.582075  14.484351  14.0  57.0  67.0  75.0  96.0
# balance         11660.0  64.709348  14.131318  17.0  57.0  67.0  75.0  97.0
# jumping         11660.0  65.036621  12.017118  25.0  58.0  66.0  73.0  95.0
# interceptions   11694.0  46.815119  20.808153   5.0  26.0  52.0  65.0  95.0
# positioning     11694.0  52.485890  19.069465   2.0  43.0  57.0  66.0  96.0
# vision          11660.0  55.439194  13.695285  10.0  47.0  57.0  65.0  95.0
# composure       11422.0  59.947732  11.769872  12.0  53.0  61.0  68.0  96.0
# sliding tackle  11660.0  45.827702  21.217062   6.0  25.0  52.0  64.0  90.0

# %%
fifa21_numerical_mean = fifa21_numerical.copy()
for column in ['volleys', 'curve', 'agility', 'balance', 'jumping','interceptions','positioning','vision','composure','sliding tackle']:
    mean = fifa21_numerical_mean[column].mean()
    fifa21_numerical_mean[column] = fifa21_numerical_mean[column].fillna(mean)   
    
fifa21_numerical_mean.isna().sum()
# Out:
# id                  0
# age                 0
# growth              0
# attacking           0
# crossing            0
# finishing           0
# heading accuracy    0
# short passing       0
# volleys             0
# skill               0
# dribbling           0
# curve               0
# fk accuracy         0
# long passing        0
# ball control        0
# movement            0
# acceleration        0
# sprint speed        0
# agility             0
# reactions           0
# balance             0
# power               0
# shot power          0
# jumping             0
# stamina             0
# strength            0
# long shots          0
# mentality           0
# aggression          0
# interceptions       0
# positioning         0
# vision              0
# penalties           0
# composure           0
# defending           0
# marking             0
# standing tackle     0
# sliding tackle      0
# goalkeeping         0
# gk diving           0
# gk handling         0
# ...

# %%
#Function cleaning

# %%
def height(text):
    return text.replace("'", ".").replace('"' , '')

def stars(text):
    return text[0]

def money(text):
    return text.replace("€", "").replace("K", "").replace("M", "")

def weight(text):
    return text.replace("lbs", "")

def add_values(text):
    return sum([int(x) for x in text.split('+')])
    
def clean_fifa21(df):
    df2 = df.copy()
    #Uniform columns names
    df2.columns= df2.columns.str.lower()
 
    #Clean numerical columns
    df2_numerical = df2.select_dtypes(include=np.number).copy()

    for column in ['volleys', 'curve', 'agility', 'balance', 'jumping','interceptions','positioning','vision','composure','sliding tackle']:
        mean = df2_numerical[column].mean()
        df2_numerical[column] = df2_numerical[column].fillna(mean)
        
    #Clean categorical columns
    df2_categorical = df2.select_dtypes(exclude=np.number).copy()
    for column in ['club', 'position', 'joined', 'a/w', 'd/w']:
        mode = df2_categorical[column].mode()
        df2_categorical[column] = df2_categorical[column].fillna(mode[0])
        
    df2_categorical = df2_categorical.drop(['loan date end'], axis=1) # axis = 1 -> columns

    for col in ['height']:
        df2_categorical[col] = df2_categorical[col].apply(height)
    
    for col in ['w/f','sm', 'ir']:
        df2_categorical[col] = df2_categorical[col].apply(stars)
    
    for col in ['value','wage', 'release clause','hits']:
        df2_categorical[col] = df2_categorical[col].apply(money)
    
    for col in ['weight']:
        df2_categorical[col] = df2_categorical[col].apply(weight)
    
    df2_categorical_l=df2_categorical.iloc[:,:20]
    df2_categorical_r=df2_categorical.iloc[:,21:]
    for col in df2_categorical_r.columns:
        df2_categorical_r[col] = df2_categorical_r[col].apply(add_values)
        
    #Concatenate 
    df2= pd.concat([df2_categorical_l,df2_categorical_r,df2_numerical], axis=1)
   
    return df2

# %%
pd.set_option('display.max_columns', None)
clean_fifa21(fifa21)
# Out:
# /var/folders/2b/pl6pxkts27ndv0n10fzpqb5m0000gn/T/ipykernel_4810/3622981961.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_categorical_r[col] = df2_categorical_r[col].apply(add_values)
#                  name  nationality                        club   bp  \
# 0           A. Pasche  Switzerland           FC Lausanne-Sport   CM
# 1       Alan Carvalho     China PR     Beijing Sinobo Guoan FC   ST
# 2         S. Giovinco        Italy                    Al Hilal  CAM
# 3            J. Evans        Wales                Swansea City  CDM
# 4          Y. Demoncy       France  US Orléans Loiret Football  CDM
# ...               ...          ...                         ...  ...
# ...

# %%
fifa21_clean = clean_fifa21(fifa21)
# Out:
# /var/folders/2b/pl6pxkts27ndv0n10fzpqb5m0000gn/T/ipykernel_4810/3622981961.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_categorical_r[col] = df2_categorical_r[col].apply(add_values)

# %%
fifa21_clean.head()
# Out:
#             name  nationality                        club   bp  position  \
# 0      A. Pasche  Switzerland           FC Lausanne-Sport   CM    CM CDM
# 1  Alan Carvalho     China PR     Beijing Sinobo Guoan FC   ST  ST LW LM
# 2    S. Giovinco        Italy                    Al Hilal  CAM    CAM CF
# 3       J. Evans        Wales                Swansea City  CDM    CDM CM
# 4     Y. Demoncy       France  US Orléans Loiret Football  CDM    CDM CM
#
#                                 team & contract height weight   foot  \
# 0                 FC Lausanne-Sport 2015 ~ 2020    5.9    161  Right
# 1  Beijing Sinobo Guoan FC Dec 31, 2020 On Loan    6.0    159  Right
# 2                          Al Hilal 2019 ~ 2022    5.4    134  Right
# 3                      Swansea City 2016 ~ 2021   5.10    152  Right
# 4        US Orléans Loiret Football 2018 ~ 2021   5.11    150  Right
#
#          joined value wage release clause              contract w/f sm  \
# ...

# %%
fifa21_clean.isna().sum()
# Out:
# name           0
# nationality    0
# club           0
# bp             0
# position       0
#               ..
# pas            0
# dri            0
# def            0
# phy            0
# ova            0
# Length: 99, dtype: int64

# %%
fifa21_clean.info()
pd.set_option('display.max_columns', None)
fifa21_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11701 entries, 0 to 11700
# Data columns (total 99 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              11701 non-null  object
#  1   nationality       11701 non-null  object
#  2   club              11701 non-null  object
#  3   bp                11701 non-null  object
#  4   position          11701 non-null  object
#  5   team & contract   11701 non-null  object
#  6   height            11701 non-null  object
#  7   weight            11701 non-null  object
#  8   foot              11701 non-null  object
#  9   joined            11701 non-null  object
#  10  value             11701 non-null  object
#  11  wage              11701 non-null  object
#  12  release clause    11701 non-null  object
#  13  contract          11701 non-null  object
#  14  w/f               11701 non-null  object
#  15  sm                11701 non-null  object
# ...

# %%
# convert just columns "a" and "b"
#df[["a", "b"]] = df[["a", "b"]].apply(pd.to_numeric)

fifa21_clean[["height",'weight', 'value', 'release clause','w/f', 'ir', 'hits']]=fifa21_clean[["height",'weight', 'value', 'release clause','w/f', 'ir', 'hits']].apply(pd.to_numeric)
fifa21_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11701 entries, 0 to 11700
# Data columns (total 99 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              11701 non-null  object
#  1   nationality       11701 non-null  object
#  2   club              11701 non-null  object
#  3   bp                11701 non-null  object
#  4   position          11701 non-null  object
#  5   team & contract   11701 non-null  object
#  6   height            11701 non-null  float64
#  7   weight            11701 non-null  int64
#  8   foot              11701 non-null  object
#  9   joined            11701 non-null  object
#  10  value             11701 non-null  float64
#  11  wage              11701 non-null  object
#  12  release clause    11701 non-null  float64
#  13  contract          11701 non-null  object
#  14  w/f               11701 non-null  int64
#  15  sm                11701 non-null  object
# ...

# %%
fifa21_clean_numerical = fifa21_clean.select_dtypes(include=np.number).copy()

# %%
fifa21_clean_numerical.head()
# Out:
#    height  weight  value  release clause  w/f  ir  hits  st  rs  lw  lf  cf  \
# 0    5.90     161  525.0           801.0    4   1   3.0  59  59  61  62  62
# 1    6.00     159    8.5             0.0    3   2  44.0  77  77  77  77  77
# 2    5.40     134    9.0            15.3    4   2  73.0  75  75  80  79  79
# 3    5.10     152  275.0           694.0    2   1   7.0  52  52  51  51  51
# 4    5.11     150  725.0             1.4    2   1   4.0  58  58  59  59  59
#
#    rf  rw  lam  cam  ram  lm  lcm  cm  rcm  rm  lwb  ldm  cdm  rdm  rwb  lb  \
# 0  62  61   64   64   64  64   64  64   64  64   60   60   60   60   60  59
# 1  77  77   77   77   77  77   70  70   70  77   59   55   55   55   59  55
# 2  79  80   80   80   80  80   76  76   76  80   61   58   58   58   61  55
# 3  51  51   55   55   55  55   58  58   58  55   58   60   60   60   58  59
# 4  59  59   63   63   63  64   65  65   65  64   66   66   66   66   66  65
#
# ...

# %%
correlations_matrix = fifa21_clean_numerical.corr()
correlations_matrix
# Out:
#                   height    weight     value  release clause       w/f  \
# height          1.000000  0.462973 -0.000452        0.014387 -0.115069
# weight          0.462973  1.000000 -0.022092       -0.019316 -0.119104
# value          -0.000452 -0.022092  1.000000        0.240130 -0.062775
# release clause  0.014387 -0.019316  0.240130        1.000000 -0.081394
# w/f            -0.115069 -0.119104 -0.062775       -0.081394  1.000000
# ...                  ...       ...       ...             ...       ...
# pas            -0.136821 -0.100392 -0.239453       -0.302069  0.225219
# dri            -0.198531 -0.210029 -0.215626       -0.298679  0.253495
# def             0.037242  0.101667 -0.092231       -0.113156 -0.063835
# phy             0.250980  0.538053 -0.121456       -0.184032 -0.009979
# ova             0.033600  0.149397 -0.320554       -0.426976  0.195136
#
#                       ir      hits        st        rs        lw        lf  \
# ...

# %%
fig, ax = plt.subplots(figsize=(25,15))
sns.heatmap(correlations_matrix) # annot = True displays the correlation values, annot=False hides the correlation values
plt.show()

# %%
#y = data['OVA'] #COLUMN WE WANT TO PREDICT
#X = data.drop(['OVA'], axis=1) #THE COLUMNS WE WANT TO USE TO PREDICT SO EXCLUDING THE OVA
#ict.values(), dict.keys(), dict.items()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/2b/pl6pxkts27ndv0n10fzpqb5m0000gn/T/ipykernel_4810/273610156.py in <module>
#       1 #y = data['OVA'] #COLUMN WE WANT TO PREDICT
#       2 #X = data.drop(['OVA'], axis=1) #THE COLUMNS WE WANT TO USE TO PREDICT SO EXCLUDING THE OVA
# ----> 3 dict.values(), dict.keys(), dict.items()
#
# TypeError: unbound method dict.values() needs an argument

# %%
correl = [(abs(item[1]),item[0]) for item in list(correlations_matrix['ova'].items())]
correl.sort(reverse=True)
correl
# Out:
# [(1.0, 'ova'),
#  (0.870246862411821, 'reactions'),
#  (0.8343306473965503, 'base stats'),
#  (0.7032896338680532, 'pas'),
#  (0.6928258250849237, 'composure'),
#  (0.6466777943081873, 'dri'),
#  (0.608433277490728, 'total stats'),
#  (0.5966416928271429, 'growth'),
#  (0.5478394760982961, 'power'),
#  (0.54248492690814, 'phy'),
#  (0.5392883096939861, 'shot power'),
#  (0.529654493663301, 'rcm'),
#  (0.529654493663301, 'lcm'),
#  (0.529654493663301, 'cm'),
#  (0.5197985417360813, 'age'),
#  (0.5072198967586743, 'vision'),
#  (0.494590242707708, 'mentality'),
#  (0.4931520441513738, 'short passing'),
#  (0.49201850089592347, 'sho'),
#  (0.4794542524531436, 'long passing'),
#  (0.4725617413386933, 'ram'),
#  (0.4725617413386933, 'lam'),
#  (0.4725617413386933, 'cam'),
#  (0.4652741301482091, 'ir'),
#  (0.46415760712132786, 'rdm'),
#  (0.46415760712132786, 'ldm'),
#  (0.46415760712132786, 'cdm'),
#  (0.4636360290980824, 'st'),
#  (0.4636360290980824, 'rs'),
# ...

# %%
reduced_corr = correlations_matrix.loc[['reactions','base stats','pas','composure','ova'],['reactions','base stats','pas','composure','ova']]

# %%
reduced_corr
# Out:
#             reactions  base stats       pas  composure       ova
# reactions    1.000000    0.744947  0.627128   0.680988  0.870247
# base stats   0.744947    1.000000  0.850402   0.608444  0.834331
# pas          0.627128    0.850402  1.000000   0.530700  0.703290
# composure    0.680988    0.608444  0.530700   1.000000  0.692826
# ova          0.870247    0.834331  0.703290   0.692826  1.000000

# %%
fig, ax = plt.subplots(figsize=(15,5))
sns.heatmap(reduced_corr, annot= True) # annot = True displays the correlation values, annot=False hides the correlation values
plt.show()

# %%
X =fifa21_clean_numerical[['reactions','base stats','pas','composure','ova']]
X.head()
# Out:
#    reactions  base stats  pas  composure  ova
# 0         66         357   63       54.0   64
# 1         75         412   68       70.0   77
# 2         78         404   78       82.0   80
# 3         55         329   54       48.0   59
# 4         62         360   60       58.0   65

# %%
sns.scatterplot(x=fifa21_clean_numerical['reactions'], y=fifa21_clean_numerical['ova'])
plt.show()

# %%
X.head()
# Out:
#    reactions  base stats  pas  composure  ova
# 0         66         357   63       54.0   64
# 1         75         412   68       70.0   77
# 2         78         404   78       82.0   80
# 3         55         329   54       48.0   59
# 4         62         360   60       58.0   65

# %%
sns.boxplot(x=fifa21_clean_numerical['reactions'])
plt.show()

# %%
sns.displot(fifa21_clean_numerical['reactions'])
plt.show()

# %%
iqr = np.percentile(X['reactions'],75) - np.percentile(X['reactions'],25)
upper_limit = np.percentile(X['reactions'],75) + 1.5*iqr
lower_limit = np.percentile(X['reactions'],25) - 1.5*iqr

# %%
lower_limit
# Out:
# 39.0

# %%
upper_limit
# Out:
# 87.0

# %%
X.shape
# Out:
# (11701, 5)

# %%
X_2 = X[(X['reactions']>lower_limit) & (X['reactions']<upper_limit)]
sns.displot(X['reactions'])
plt.show()

# %%
X_2.shape
# Out:
# (11563, 5)

# %%
sns.boxplot(x=X_2['reactions'])
plt.show()

# %%
sns.scatterplot(x=fifa21_clean_numerical_2['base stats'], y=fifa21_clean_numerical['ova'])
plt.show()

# %%
sns.displot(fifa21_clean_numerical_2['base stats'])
plt.show()

# %%
sns.boxplot(x=fifa21_clean_numerical_2['base stats'])
plt.show()

# %%
sns.scatterplot(x=fifa21_clean_numerical_2['pas'], y=fifa21_clean_numerical['ova'])
plt.show()

# %%
sns.boxplot(x=fifa21_clean_numerical_2['pas'])
plt.show()

# %%
sns.displot(fifa21_clean_numerical_2['pas'])
plt.show()

# %%
sns.scatterplot(x=fifa21_clean_numerical_2['composure'], y=fifa21_clean_numerical['ova'])
plt.show()

# %%
sns.boxplot(x=fifa21_clean_numerical_2['composure'])
plt.show()

# %%
iqr = np.percentile(X_2['composure'],75) - np.percentile(X_2['composure'],25)
upper_limit = np.percentile(X_2['composure'],75) + 1*iqr
lower_limit = np.percentile(X_2['composure'],25) - 1*iqr

# %%
upper_limit
# Out:
# 83.0

# %%
lower_limit
# Out:
# 38.0

# %%
X_2.shape
# Out:
# (11563, 5)

# %%
X_3 = X_2[(X_2['composure']>lower_limit) & (X_2['composure']<upper_limit)]
sns.displot(X_2['composure'])
plt.show()

# %%
X_3.shape
# Out:
# (10974, 5)

# %%
sns.boxplot(x=X_3['composure'])
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler # do not use the function Normalise() - it does something entirely different
from sklearn.preprocessing import StandardScaler

# %%
X_1 = X_3[['reactions','base stats','pas','composure']]
y = X_3['ova']

# %%
X_1.head()
# Out:
#    reactions  base stats  pas  composure
# 0         66         357   63       54.0
# 1         75         412   68       70.0
# 2         78         404   78       82.0
# 3         55         329   54       48.0
# 4         62         360   60       58.0

# %%
# Normalizing data: make data range from 0 - 1, instead of from min to max
transformer = MinMaxScaler().fit(X_1)
X_3_normalized = transformer.transform(X_1)
display(X_3_normalized)
print(X_3_normalized.shape)
X_3_normalized
X_3_normalized_df = pd.DataFrame(X_3_normalized, columns=X_1.columns)
# Out:
# array([[0.56521739, 0.50390625, 0.59677419, 0.34883721],
#        [0.76086957, 0.71875   , 0.67741935, 0.72093023],
#        [0.82608696, 0.6875    , 0.83870968, 1.        ],
#        ...,
#        [0.47826087, 0.42578125, 0.5483871 , 0.44186047],
#        [0.32608696, 0.671875  , 0.70967742, 0.48715657],
#        [0.45652174, 0.421875  , 0.48387097, 0.39534884]])
# (10974, 4)

# %%
sns.displot(X_3_normalized_df['composure'])
plt.show()

# %%
X_3_normalized_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10974 entries, 0 to 10973
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   reactions   10974 non-null  float64
#  1   base stats  10974 non-null  float64
#  2   pas         10974 non-null  float64
#  3   composure   10974 non-null  float64
# dtypes: float64(4)
# memory usage: 343.1 KB

# %%
# scaling standard scaler: make data distributed with mean=0 and std=1
transformer = StandardScaler().fit(X_3_normalized)
X_3_normalized_standard = transformer.transform(X_3_normalized)
print(X_3_normalized_standard.shape)
X_3_normalized_standard_df = pd.DataFrame(X_3_normalized_standard, columns=X_3_normalized_df.columns)
# Out:
# (10974, 4)

# %%
sns.displot(X_3_normalized_standard_df['composure'])
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %%
X_4 = X_3_normalized_standard_df
X_4.head()
# Out:
#    reactions  base stats       pas  composure
# 0   0.337377   -0.126592  0.418921  -0.727653
# 1   1.425457    1.288586  0.921658   0.935255
# 2   1.788150    1.082742  1.927134   2.182436
# 3  -0.992499   -0.847046 -0.486007  -1.351243
# 4  -0.146214   -0.049400  0.117278  -0.311926

# %%
X_4_train, X_4_test, y_train, y_test = train_test_split(X_4, y, test_size=0.2, random_state=42)

# %%
y_2 = pd.DataFrame(y)
y_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10974 entries, 0 to 11700
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ova     10974 non-null  int64
# dtypes: int64(1)
# memory usage: 171.5 KB

# %%
print(X_4_train.shape)
print(X_4_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (8779, 4)
# (2195, 4)
# (8779,)
# (2195,)

# %%
#we train/fit our model 
lm = LinearRegression()
lm.fit(X_4_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score
y_pred_train = lm.predict(X_4_train)
r2_score(y_train, y_pred_train)
# Out:
# 0.821878019095887

# %%
y_pred_test = lm.predict(X_4_test)
r2_score(y_test, y_pred_test)
# Out:
# 0.8331110807051456

# %%
y_pred_test
# Out:
# array([75.06216697, 64.24473798, 66.92313058, ..., 64.82147559,
#        72.4741306 , 54.30060295])

# %%
from sklearn.metrics import mean_squared_error
# Comptuing the RMSE -> root mean squared error.
np.sqrt(mean_squared_error(y_test,y_pred_test))
# Out:
# 2.5907710543597737

# %%
rmse=np.sqrt(mean_squared_error(y_test,y_pred_test))
rmse
# Out:
# 2.5907710543597737

# %%
#Make it in a function
